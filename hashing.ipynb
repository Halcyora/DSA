# %%
n = [ 2, 3, 12, 23, 23, 60, 112, 13, 23, 2 ]
m = [ 2, 4, 6, 23, 112 ]

# %%
h = {}
for i  in range(len(n)):
    h[n[i]] = h.get(n[i],0)+1
print(h)
# Out:
# {2: 2, 3: 1, 12: 1, 23: 3, 60: 1, 112: 1, 13: 1}

# %%
for i in m:
    if i in h:
        print(i, ":", h[i])
# Out:
# 2 : 2
# 23 : 3
# 112 : 1
