# %%
n = 1634

# %%
c = 0
num1 = n
while num1 > 0:
    c+=1
    num1 //= 10

print(c)
# Out:
# 4

# %%
a = 0
num2 = n
for i in range(c):
    r = num2 % 10
    a+=(r**c)
    num2 //= 10

print(a)
# Out:
# 1634

# %%
if (n==a):
    print("Armstrong")
else:
    print("Nope")
# Out:
# Armstrong
